# %%
# Импорт всех библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Модели и разбиение данных
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Метрики качества
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Настройка отображения графиков в Jupyter
# %matplotlib inline

df = pd.read_excel("Линейная регрессия.xlsx")

# %%
print(df.head()) #первые 5 строк
print(df.info()) 
print(df.describe())
print(df.isnull().sum())
# Out:
#       price  total_area  living_area  number_of_rooms  balcony repair  \
# 0  22000000       101.5         71.4                5        0   good
# 1  11500000        77.7         52.7                4        1   good
# 2   5700000        33.2         18.5                1        1    bad
# 3   8950000        55.9         31.9                2        1   good
# 4  11500000        82.3         57.2                4        0   good
#
#    building_year  distance_park_km  first_or_last_floor
# 0           1940               0.1                    0
# 1           1991               0.2                    0
# 2           1983               0.7                    0
# 3           1982               0.6                    0
# 4           1982               0.6                    1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                167 non-null    int64
#  1   total_area           167 non-null    float64
#  2   living_area          167 non-null    float64
#  3   number_of_rooms      167 non-null    int64
#  4   balcony              167 non-null    int64
#  5   repair               167 non-null    object
#  6   building_year        167 non-null    int64
#  7   distance_park_km     167 non-null    float64
#  8   first_or_last_floor  167 non-null    int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 11.9+ KB
# None
#               price  total_area  living_area  number_of_rooms     balcony  \
# count  1.670000e+02  167.000000   167.000000       167.000000  167.000000
# mean   1.009340e+07   58.721557    35.463473         2.113772    0.640719
# std    6.865085e+06   36.075587    23.534208         0.965796    0.540209
# min    3.890000e+06   23.900000    12.000000         1.000000    0.000000
# 25%    6.250000e+06   37.650000    18.700000         1.000000    0.000000
# 50%    8.250000e+06   51.000000    29.900000         2.000000    1.000000
# 75%    1.150000e+07   66.650000    41.900000         3.000000    1.000000
# max    7.100000e+07  315.600000   133.000000         5.000000    2.000000
#
#        building_year  distance_park_km  first_or_last_floor
# count     167.000000        167.000000           167.000000
# mean     1986.323353          0.420898             0.455090
# std        22.100610          0.254962             0.499477
# min      1917.000000          0.010000             0.000000
# 25%      1967.000000          0.200000             0.000000
# 50%      1982.000000          0.400000             0.000000
# 75%      2009.500000          0.700000             1.000000
# max      2021.000000          0.900000             1.000000
# price                  0
# total_area             0
# living_area            0
# number_of_rooms        0
# balcony                0
# repair                 0
# building_year          0
# distance_park_km       0
# first_or_last_floor    0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Распределение цен на квартиры в Петергофе')
plt.xlabel('Цена (руб)')
plt.ylabel('Количество квартир')
plt.ticklabel_format(axis='x', style='plain')  #убираем 1e7
plt.show()

# %%
print(df['price'].describe())
# Out:
# count    1.670000e+02
# mean     1.009340e+07
# std      6.865085e+06
# min      3.890000e+06
# 25%      6.250000e+06
# 50%      8.250000e+06
# 75%      1.150000e+07
# max      7.100000e+07
# Name: price, dtype: float64

# %%
#максимальное сильно больше медианы.нужно удалить.
plt.figure(figsize=(8, 4))
plt.boxplot(df['price'])
plt.title('Выбросы в ценах')
plt.ylabel('Цена (руб)')
plt.ticklabel_format(axis='y', style='plain')
plt.show()

# %%
# Удаляем строки с ценой выше 25 млн
df = df[df['price'] <= 25000000]

print(len(df))
print(df['price'].describe())
# Out:
# 165
# count    1.650000e+02
# mean     9.549079e+06
# std      4.437497e+06
# min      3.890000e+06
# 25%      6.200000e+06
# 50%      8.100000e+06
# 75%      1.150000e+07
# max      2.455000e+07
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Распределение цен на квартиры в Петергофе')
plt.xlabel('Цена (руб)')
plt.ylabel('Количество квартир')
plt.ticklabel_format(axis='x', style='plain')  #убираем 1e7
plt.show()

plt.figure(figsize=(8, 4))
plt.boxplot(df['price'])
plt.title('Выбросы в ценах')
plt.ylabel('Цена (руб)')
plt.ticklabel_format(axis='y', style='plain')
plt.show()
#повторяем без выбросов

# %%
#необходимо заменить значения "ремонта" на числовые.


df['repair'] = df['repair'].astype(str).str.strip().str.lower()

condition_map = {
    'none': 0,
    'bad': 1,
    'good': 2,
    'perfect': 3
}
df['repair'] = df['repair'].map(condition_map)

print(df['repair'].value_counts())
# Out:
# repair
# 2    106
# 1     25
# 3     18
# 0     16
# Name: count, dtype: int64

# %%
correlations = df.corr()['price'].sort_values(ascending=False)
print(correlations)
df.hist(figsize=(15, 10), bins=20, edgecolor='black')
plt.suptitle('Распределение признаков')
plt.show()
# Out:
# price                  1.000000
# total_area             0.773030
# living_area            0.716058
# number_of_rooms        0.670615
# building_year          0.097509
# first_or_last_floor    0.028839
# repair                -0.119741
# balcony               -0.179348
# distance_park_km      -0.271534
# Name: price, dtype: float64

# %%
#видим, что балкон, этажность и состояние ремонта имеют низкую корреляцию. Для линейной регрессии это не очень хорошо, для случайного леса - не существенно. Для сравнения я не буду удалять эти признаки.

# %%
x = df.drop('price', axis=1)
y = df['price'] #целевая переменная - y. предсказывается по х.

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) #разделили на обучающую и тестовую выборку 80\20

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

print("=== Linear Regression ===")
print(f"MAE: {mean_absolute_error(y_test, lr_pred):.0f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, lr_pred)):.0f}")
print(f"R2: {r2_score(y_test, lr_pred):.3f}")
# Out:
# === Linear Regression ===
# MAE: 2198383
# RMSE: 2724524
# R2: 0.682

# %%
#Вывод: модель работает. 23% вариации цены модель не уловила — нужны более качественные признаки или нелинейные зависимости.
plt.scatter(y_test, lr_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Реальная цена')
plt.ylabel('Предсказанная цена')
plt.title('Линейная регрессия: реальные vs предсказанные цены')
plt.show() 

residuals = y_test - lr_pred
plt.hist(residuals, bins=20, edgecolor='black')
plt.title('Распределение ошибок линейной регрессии')
plt.xlabel('Ошибка (реальная - предсказанная)')
plt.ylabel('Частота')
plt.show() #график ошибок

# %%
df_rf = pd.read_excel('Random Forest.xlsx')

df_rf['repair'] = df_rf['repair'].astype(str).str.strip().str.lower()

condition_map2 = {
    'none': 0,
    'bad': 1,
    'good': 2,
    'perfect': 3
}
df_rf['repair'] = df_rf['repair'].map(condition_map2)

# %%
print(df_rf['price'].describe())
X_rf = df_rf.drop('price', axis=1)
y_rf = df_rf['price']

X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_rf, y_rf, test_size=0.2, random_state=42)

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train_rf, y_train_rf)
rf_pred = rf.predict(X_test_rf)

print("=== Random Forest (полные данные) ===")
print(f"MAE: {mean_absolute_error(y_test_rf, rf_pred):.0f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test_rf, rf_pred)):.0f}")
print(f"R2: {r2_score(y_test_rf, rf_pred):.3f}")
# Out:
# count    1.670000e+02
# mean     1.009340e+07
# std      6.865085e+06
# min      3.890000e+06
# 25%      6.250000e+06
# 50%      8.250000e+06
# 75%      1.150000e+07
# max      7.100000e+07
# Name: price, dtype: float64
# === Random Forest (полные данные) ===
# MAE: 1157150
# RMSE: 1821614
# R2: 0.864

# %%
plt.scatter(y_test_rf, rf_pred, alpha=0.5)
plt.plot([y_test_rf.min(), y_test_rf.max()], [y_test_rf.min(), y_test_rf.max()], 'r--', lw=2)
plt.xlabel('Реальная цена')
plt.ylabel('Предсказанная цена')
plt.title('Random Forest: реальные vs предсказанные цены')
plt.show()

residuals_rf = y_test_rf - rf_pred
plt.hist(residuals_rf, bins=20, edgecolor='black')
plt.title('Распределение ошибок Random Forest')
plt.xlabel('Ошибка (реальная - предсказанная)')
plt.ylabel('Частота')
plt.show()

# %%
#проверим модель на новой квартире, не принадлежащей выборке
new_flat = pd.DataFrame([[
    56.6,   # total_area
    31.0,   # living_area
    2,      # number_of_rooms
    1,      # balcony (1 - есть)
    2,      # repair (0=none,1=bad,2=good,3=perfect)
    5,      # floor
    6,      # total_floor
    2018,   # building_year
    0.8     # distance_park_km
]], columns=['total_area', 'living_area', 'number_of_rooms', 'balcony', 'repair', 'floor', 'total_floor', 'building_year', 'distance_park_km'])

predicted_price = rf.predict(new_flat)
print(f"Предсказанная цена: {predicted_price[0]:.0f} рублей")
# Out:
# Предсказанная цена: 11816590 рублей

# %%
print(f"Реальная цена: 12 600 000 ₽")
print(f"Прогноз модели Сбера(Домклик): 11 800 000 ₽")
print(f"Прогноз моей модели: 11 816 590 ₽")
print(f"Совпадение: ~99%")
# Out:
# Реальная цена: 12 600 000 ₽
# Прогноз модели Сбера(Домклик): 11 800 000 ₽
# Прогноз моей модели: 11 816 590 ₽
# Совпадение: ~99%
